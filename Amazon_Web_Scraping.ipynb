# %% [markdown]
# <h1 align="center"> WEB SCRAPING USING PYTHON </h1>
# <h4 align="center"> (Scraping Top 50 Best-Selling Electronic Items) </h4>

# %% [markdown]
# #### Importing Required Libraries

# %%
from bs4 import BeautifulSoup

import lxml

import requests

import pandas as pd
import numpy as np

# %% [markdown]
# #### Make HTTP requests to get the data from the website

# %%
html_text = requests.get('https://www.amazon.in/gp/bestsellers/electronics').text

# %% [markdown]
# #### ***Beautiful Soup*** is a Python library that is used for web scraping purposes to pull the data out of HTML and XML files. It creates a parse tree from page source code that can be used to extract data in a hierarchical and more readable manner.

# %%
soup = BeautifulSoup(html_text,'lxml')

# %% [markdown]
# #### *Get model Name, Rating, Offer Type, Current Price, Actual Price and URL to the Page using HTML tags and Class* (Try first with "find" if the data is exactly what you want then to extract entire data use "find_all")
# Whenever you see ***soup.find***, it means we are trying to find an element of the page using its HTML tag (like div, or span, etc.) and/or attributes (name, id, class, etc.)

# %%
## For trail  
electronic = soup.find('span', class_ ="a-list-item")
name_c = electronic.find('div', class_="p13n-sc-truncate p13n-sc-line-clamp-3").text.strip()

current_price_c = electronic.find('span', class_ ="p13n-sc-price").text
more_info_c = 'https://www.amazon.in' + electronic.a['href']


# to prevent script from crashing when there is no rating for the product
try:
    rating_c = float(electronic.find('span', class_="a-icon-alt").text.split()[0])
except:
    rating_c = 'NA'
try:
    users_rated_c = int(electronic.find('span', class_="a-size-small a-color-secondary").text)
except:
    users_rated_c = 0

# %%
print(name_c)
print(rating_c)
print(current_price_c)
print(more_info_c)
print(users_rated_c)
# Out:
# OnePlus Nord 2 5G (Blue Haze, 8GB RAM, 128GB Storage) I Extra upto Rs.1000 off on Exchange
# NA
# ₹29,999.00
# https://www.amazon.in/OnePlus-128GB-Storage-Rs-1000-Exchange/dp/B097RD2JX8?_encoding=UTF8&psc=1
# 0

# %% [markdown]
# #### Extract entire data using 'find_all' and run a FOR LOOP to get the data for all the mobile phones
#
# >***Final Execution:*** Since most of my values are coming true for the first product. Now, I can run *find_all* to extract the tags of all the products in Bestseller List

# %%
electronics_dataset = soup.find_all('span', class_ ="a-list-item")

# %%
## Created empty list for the variables we want to extract
Name = []
Rating = []
Price = []
Users_rated = []
More_info = []

# %% [markdown]
# ###### Running FOR LOOP and appending the variables with the data

# %%
for i in electronics_dataset :
    try:
        name = i.find('div', class_="p13n-sc-truncate p13n-sc-line-clamp-3").text.strip()
    except:
        name = i.find('div', class_="p13n-sc-truncate p13n-sc-line-clamp-2").text.strip()
    try:
        price = float(i.find('span', class_ ="p13n-sc-price").text.replace(",","")[1:])
    except:
        price = 'NA'
    more_info = 'https://www.amazon.in' + i.a['href']
    try:
        rating = float(i.find('span', class_="a-icon-alt").text.split()[0])
    except:
        rating = 'NA'
    
    try:
        users_rated = int(i.find('a', class_="a-size-small a-link-normal").text.replace(",",""))
    except:
        users_rated = 0
    Name.append(name)
    Price.append(price)
    Rating.append(rating)
    Users_rated.append(users_rated)
    More_info.append(more_info)

# %% [markdown]
# ###### Creating Dictionary out of the Variables

# %%
Electronic_dict = {'Name': Name, 'Price': Price, 'Ratings':Rating, 'No. of Users Rated': Users_rated, 'URL': More_info}
Electronic_dict
# Out:
# {'Name': ['OnePlus Nord 2 5G (Blue Haze, 8GB RAM, 128GB Storage) I Extra upto Rs.1000 off on Exchange',
#   'OnePlus Nord 2 5G (Gray Sierra, 8GB RAM, 128GB Storage) I Extra upto Rs.1000 off on Exchange',
#   'Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage) -Amoled Dot Display | 48MP Sony Sensor IMX582 | Snapdragon 678 Processor',
#   'Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) | Extra INR 200 Amazon Pay Cashback | 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#   'Redmi 9A (Sea Blue 2GB RAM 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#   'Redmi 9A (Midnight Black 2GB RAM 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#   'Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB Storage) -Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen Replacement (Prime only)|Extra INR 1000 Off Through Coupons',
#   'Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime',
#   'Echo Dot (3rd Gen, Black) + Wipro 9W LED Smart Color Bulb combo - Works with Alexa - Smart Home starter kit',
#   'OnePlus Nord CE 5G (Charcoal Ink, 6GB RAM, 128GB Storage)',
#   'Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) | Extra INR 200 Amazon Pay Cashback | 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'boAt Airdopes 141 True Wireless Earbuds with 42 Hours Playback, Fast Charge, IWP Technology, IPX4, Bluetooth v5.0 and Voice Assistant(Active Black)',
#   'Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Storage) - Amoled Dot Display | 48MP Sony Sensor IMX582 | Snapdragon 678 Processor',
#   'Samsung Galaxy M31s (Mirage Blue, 8GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime',
#   'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | Extra INR 200 Amazon Pay Cashback | 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'Redmi Note 10 (Frost White, 4GB RAM, 64GB Storage) - Super Amoled Dot Display | 48MP Sony Sensor IMX582 | Snapdragon 678 Processor',
#   'OnePlus Bullets Wireless Z Bass Edition (Bold Black)',
#   'realme C11 (2021) (Cool Blue, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'Redmi Note 10S (Shadow Black, 6GB RAM, 64GB Storage) - Super Amoled Display | 64 MP Quad Camera | 6 Month Free Screen Replacement (Prime only)|Extra INR 1000 Off Through Coupons',
#   'Samsung Galaxy M31s (Mirage Black, 6GB RAM, 128GB Storage) 6 Months Free Screen Replacement for Prime',
#   'realme C11 (2021) (Cool Grey, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'boAt Bassheads 100 in Ear Wired Earphones with Mic(Black)',
#   'boAt Bassheads 242 in Ear Wired Earphones with Mic(Active Black)',
#   'boAt Airdopes 121v2 TWS Earbuds with Bluetooth V5.0, Immersive Audio, Up to 14H Total Playback, Instant Voice Assistant, Easy Access Controls with Mic and Dual Tone Ergonomic Design(Active Black)',
#   'boAt Type C A325 Tangle-Free, Sturdy Type C Cable with 3A Rapid Charging & 480mbps Data Transmission(Black)',
#   'boAt Rockerz 450 On-Ear Headphones with 15 Hours Battery, 40mm Drivers, Padded Ear Cushions, Easy Access Controls and Voice Assistant(Luscious Black)',
#   'Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Storage) - 6000mAh Battery |FHD+ Screen| 48MP Quad Camera | Alexa Hands-Free Capable',
#   'Fire TV Stick 4K with Alexa Voice Remote | Stream in 4K resolution',
#   'OnePlus Buds Z (White)',
#   'OnePlus Nord 2 5G (Blue Haze, 12GB RAM, 256GB Storage) I Extra upto Rs.1000 off on Exchange',
#   'boAt Rockerz 255 Pro+ in-Ear Earphones with 40 Hours Battery, ASAP Charge, IPX7, Bluetooth Version 5.0, 10mm Drivers and Voice Assistant(Active Black)',
#   'OnePlus Bullets Wireless Z Bass Edition (Reverb Red)',
#   'boAt Rockerz 335 Wireless Neckband with ASAP Charge, Up to 30H Playback, Qualcomm aptX & CVC, Enhanced Bass, Metal Control Board, IPX5, Type C Port, Bluetooth v5.0, Voice Assistant(Blue Ocean)',
#   'Mi Power Bank 3i 20000mAh | 18W Fast PD Charging | Input- Type C and Micro USB| Triple Output | Sandstone Black',
#   'Redmi 9 Power (Mighty Black 4GB RAM 64GB Storage) - 6000mAh Battery |FHD+ Screen | 48MP Quad Camera | Alexa Hands-Free Capable',
#   'boAt Rockerz 255 in-Ear Earphones with 8 Hours Battery, IPX5, Bluetooth V5.0 and Voice Assistant(Active Black)',
#   'Jabra Elite 65t Alexa Enabled True Wireless Earbuds with Charging Case, 15 Hours Battery,Titanium Black, Designed in Denmark',
#   'Redmi Note 10 Pro Max (Dark Night, 6GB RAM, 128GB Storage) -108MP Quad Camera | 120Hz Super Amoled Display | 6 Month Free Screen Replacement (Prime only) | Extra 1000 Off on Coupon',
#   'OnePlus Nord CE 5G (Charcoal Ink, 8GB RAM, 128GB Storage)',
#   'Redmi Note 10 Pro Max (Glacial Blue, 6GB RAM, 128GB Storage) -108MP Quad Camera|120Hz Super Amoled Display | 6 Month Free Screen Replacement (Prime only) | Extra 1000 Off on Coupon',
#   'Apple 20W USB-C Power Adapter (for iPhone, iPad & AirPods)',
#   'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#   'OnePlus Nord 2 5G (Gray Sierra, 12GB RAM, 256GB Storage) I Extra upto Rs.1000 off on Exchange',
#   'boAt Rugged v3 Extra Tough Unbreakable Braided Micro USB Cable 1.5 Meter (Black)',
#   'Redmi 9 Prime (Space Blue, 4GB RAM, 64GB Storage)- Full HD+ Display & AI Quad Camera',
#   'Samsung Galaxy M12 (Black,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#   'boAt Rockerz 450 Bluetooth On-Ear Headphone with Mic(Aqua Blue)',
#   'Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#   'boAt Bassheads 900 On Ear Wired Headphones(Carbon Black)'],
#  'Price': [29999.0,
#   29999.0,
#   12999.0,
#   8999.0,
#   6799.0,
#   6799.0,
#   6799.0,
#   14999.0,
#   'NA',
#   3599.0,
#   22999.0,
#   8999.0,
#   1299.0,
#   12999.0,
#   16999.0,
#   8999.0,
#   12999.0,
#   1899.0,
#   'NA',
#   14999.0,
#   15499.0,
#   6699.0,
#   399.0,
#   499.0,
#   1299.0,
#   199.0,
#   999.0,
#   10999.0,
#   5999.0,
#   2999.0,
#   34999.0,
#   1279.0,
#   1999.0,
#   1599.0,
#   1699.0,
#   10999.0,
#   1199.0,
#   3999.0,
#   19999.0,
#   24999.0,
#   19999.0,
#   1800.0,
#   'NA',
#   34999.0,
#   299.0,
#   9999.0,
#   10999.0,
#   1399.0,
#   10999.0,
#   649.0],
#  'Ratings': ['NA',
#   'NA',
#   4.1,
#   4.2,
#   4.2,
#   4.2,
#   4.2,
#   4.0,
#   4.3,
#   4.4,
#   4.1,
#   4.2,
#   3.6,
#   4.1,
#   4.3,
#   4.2,
#   4.1,
#   4.3,
#   4.1,
#   4.0,
#   4.3,
#   4.1,
#   4.1,
#   4.1,
#   3.8,
#   4.3,
#   4.1,
#   4.2,
#   4.4,
#   4.2,
#   'NA',
#   4.1,
#   4.3,
#   4.0,
#   4.3,
#   4.2,
#   4.1,
#   3.9,
#   4.1,
#   4.1,
#   4.1,
#   4.5,
#   4.3,
#   'NA',
#   4.2,
#   4.3,
#   4.1,
#   4.1,
#   4.1,
#   4.2],
#  'No. of Users Rated': [0,
#   0,
#   71842,
#   66529,
#   69234,
#   69234,
#   69234,
#   5413,
#   78853,
#   62329,
#   18227,
#   66529,
#   19,
#   71841,
#   78853,
#   66529,
#   71841,
#   71396,
#   326,
#   5413,
#   78853,
#   326,
#   207396,
#   57796,
#   31862,
#   14067,
#   38397,
#   51822,
#   12779,
#   35373,
#   0,
#   283906,
#   71396,
#   25239,
#   59262,
#   51822,
#   283906,
#   7476,
#   14695,
#   18227,
#   14695,
#   10325,
#   222161,
#   0,
#   50134,
#   54138,
#   34719,
#   38397,
#   34719,
#   47268],
#  'URL': ['https://www.amazon.in/OnePlus-128GB-Storage-Rs-1000-Exchange/dp/B097RD2JX8?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-Sierra-Storage-Rs-1000-Exchange/dp/B097RDVDL2?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Test-Exclusive_2020_1140-Multi-3GB-Storage/dp/B089MT36T8?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-Carbon-Black-64GB-Storage/dp/B086985T6R?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-9A-2GB-32GB-Storage/dp/B08696XB4B?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-9A-2GB-32GB-Storage/dp/B086978F2L?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-9A-Midnight-2GB-32GB/dp/B08697N43G?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-Note-Deep-Blue-Storage/dp/B0948NNY3W?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Samsung-Galaxy-Mirage-128GB-Storage/dp/B07DJCJBB3?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Black-Wipro-Smart-Color-combo/dp/B096S89393?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-Nord-Charcoal-128GB-Storage/dp/B095735P11?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-Sporty-Orange-64GB-Storage/dp/B08696W3B3?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/boAt-Airdopes-141-Technology-Bluetooth/dp/B097GD1GPN?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/note10/dp/B089MS8NW8?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Samsung-Galaxy-Mirage-128GB-Storage/dp/B07DJCJBBN?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-Sky-Blue-64GB-Storage/dp/B08697N43N?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Test-Exclusive_2020_1141-Multi-3GB-Storage/dp/B089MS8VY3?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-Bullets-Wireless-Bass-Black/dp/B092ZJVB6Z?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/realme-Storage-Additional-Exchange-Offers/dp/B096RWS54N?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-Note-10S/dp/B08LRDM44F?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Samsung-Galaxy-Mirage-Black-Storage/dp/B07DJD1XZ4?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/realme-Storage-Additional-Exchange-Offers/dp/B096RT57F9?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/boAt-BassHeads-100-Headphones-Black/dp/B071Z8M4KX?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Boat-Bassheads-242-Earphones-Resistance/dp/B07S9S86BF?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Airdopes-121v2-Bluetooth-Immersive-Assistant/dp/B08JQN8DGZ?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/boAt-A325-Tangle-Free-Charging-Transmission/dp/B08WRBG3XW?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Rockerz-450-Wireless-Bluetooth-Headphone/dp/B07PR1CL3S?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Test-Exclusive_2020_1113-Multi-3GB-Storage/dp/B089MS8XQ3?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Amazon-FireTV-Stick-4K-Alexa-Voice-Remote-Streaming-Player/dp/B079QQZZJK?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-Buds-Z-White/dp/B07XY541GH?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-256GB-Storage-Rs-1000-Exchange/dp/B097RDF6NW?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/boAt-Rockerz-255-Pro-Earphones/dp/B08TV2P1N8?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-Bullets-Wireless-Bass-Reverb/dp/B08HLTFB33?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/boAt-Rockerz-335-Bluetooth-Assistant/dp/B096YC9Z6T?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/20000mAh-Sandstone-Triple-Charging-Delivery/dp/B08HV83HL3?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Test-Exclusive_2020_1112-Multi-3GB-Storage/dp/B089MS7D8F?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/255-Bluetooth-Wireless-Earphone-Immersive/dp/B07C2VJXP4?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Jabra-Enabled-Wireless-Charging-Titanium/dp/B079L9WYP7?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Test-Exclusive_2020_1157-Multi-3GB-Storage/dp/B089MV3Q2G?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-Nord-Charcoal-128GB-Storage/dp/B09576CYNP?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Test-Exclusive_2020_1158-Multi-3GB-Storage/dp/B089MTVYZF?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Apple-USB-C-Adapter-iPhone-AirPods/dp/B08L5WWFCY?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Samsung-Galaxy-Ocean-128GB-Storage/dp/B07HGGYWL6?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/OnePlus-Sierra-Storage-Rs-1000-Exchange/dp/B097RDPT8F?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Rugged-Extra-Tough-Unbreakable-Braided/dp/B0789LZTCJ?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Redmi-Prime-Storage-Display-Camera/dp/B08696XM8J?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Samsung-Galaxy-M12-Storage-Processor/dp/B08XJCMGL7?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Boat-Rockerz-450-Lightweight-Compatibility/dp/B08667772G?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Samsung-Galaxy-M12-Storage-Processor/dp/B08XGDN3TZ?_encoding=UTF8&psc=1',
#   'https://www.amazon.in/Boat-BassHeads-900-Wired-Headphone/dp/B074ZF7PVZ?_encoding=UTF8&psc=1']}

# %% [markdown]
# ###### Creating Dataframe from the above dictionary

# %%
df = pd.DataFrame(Electronic_dict, index=range(1,51,1))

# %% [markdown]
# #### TOP 50 Best-Selling Electronic Items

# %%
df
# Out:
#                                                  Name    Price Ratings  \
# 1   OnePlus Nord 2 5G (Blue Haze, 8GB RAM, 128GB S...  29999.0      NA
# 2   OnePlus Nord 2 5G (Gray Sierra, 8GB RAM, 128GB...  29999.0      NA
# 3   Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Stora...  12999.0     4.1
# 4   Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) ...   8999.0     4.2
# 5   Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...   6799.0     4.2
# 6   Redmi 9A (Sea Blue 2GB RAM 32GB Storage) | 2GH...   6799.0     4.2
# 7   Redmi 9A (Midnight Black 2GB RAM 32GB Storage)...   6799.0     4.2
# 8   Redmi Note 10S (Deep Sea Blue, 6GB RAM, 64GB S...  14999.0     4.0
# 9   Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128...       NA     4.3
# 10  Echo Dot (3rd Gen, Black) + Wipro 9W LED Smart...   3599.0     4.4
# 11  OnePlus Nord CE 5G (Charcoal Ink, 6GB RAM, 128...  22999.0     4.1
# 12  Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage)...   8999.0     4.2
# 13  boAt Airdopes 141 True Wireless Earbuds with 4...   1299.0     3.6
# 14  Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Sto...  12999.0     4.1
# 15  Samsung Galaxy M31s (Mirage Blue, 8GB RAM, 128...  16999.0     4.3
# 16  Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | Ex...   8999.0     4.2
# 17  Redmi Note 10 (Frost White, 4GB RAM, 64GB Stor...  12999.0     4.1
# 18  OnePlus Bullets Wireless Z Bass Edition (Bold ...   1899.0     4.3
# 19  realme C11 (2021) (Cool Blue, 2GB RAM, 32GB St...       NA     4.1
# 20  Redmi Note 10S (Shadow Black, 6GB RAM, 64GB St...  14999.0     4.0
# 21  Samsung Galaxy M31s (Mirage Black, 6GB RAM, 12...  15499.0     4.3
# 22  realme C11 (2021) (Cool Grey, 2GB RAM, 32GB St...   6699.0     4.1
# 23  boAt Bassheads 100 in Ear Wired Earphones with...    399.0     4.1
# 24  boAt Bassheads 242 in Ear Wired Earphones with...    499.0     4.1
# 25  boAt Airdopes 121v2 TWS Earbuds with Bluetooth...   1299.0     3.8
# 26  boAt Type C A325 Tangle-Free, Sturdy Type C Ca...    199.0     4.3
# 27  boAt Rockerz 450 On-Ear Headphones with 15 Hou...    999.0     4.1
# 28  Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...  10999.0     4.2
# 29  Fire TV Stick 4K with Alexa Voice Remote | Str...   5999.0     4.4
# 30                             OnePlus Buds Z (White)   2999.0     4.2
# 31  OnePlus Nord 2 5G (Blue Haze, 12GB RAM, 256GB ...  34999.0      NA
# 32  boAt Rockerz 255 Pro+ in-Ear Earphones with 40...   1279.0     4.1
# 33  OnePlus Bullets Wireless Z Bass Edition (Rever...   1999.0     4.3
# 34  boAt Rockerz 335 Wireless Neckband with ASAP C...   1599.0     4.0
# 35  Mi Power Bank 3i 20000mAh | 18W Fast PD Chargi...   1699.0     4.3
# 36  Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...  10999.0     4.2
# 37  boAt Rockerz 255 in-Ear Earphones with 8 Hours...   1199.0     4.1
# 38  Jabra Elite 65t Alexa Enabled True Wireless Ea...   3999.0     3.9
# 39  Redmi Note 10 Pro Max (Dark Night, 6GB RAM, 12...  19999.0     4.1
# 40  OnePlus Nord CE 5G (Charcoal Ink, 8GB RAM, 128...  24999.0     4.1
# 41  Redmi Note 10 Pro Max (Glacial Blue, 6GB RAM, ...  19999.0     4.1
# 42  Apple 20W USB-C Power Adapter (for iPhone, iPa...   1800.0     4.5
# 43  Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...       NA     4.3
# 44  OnePlus Nord 2 5G (Gray Sierra, 12GB RAM, 256G...  34999.0      NA
# 45  boAt Rugged v3 Extra Tough Unbreakable Braided...    299.0     4.2
# 46  Redmi 9 Prime (Space Blue, 4GB RAM, 64GB Stora...   9999.0     4.3
# 47  Samsung Galaxy M12 (Black,4GB RAM, 64GB Storag...  10999.0     4.1
# 48  boAt Rockerz 450 Bluetooth On-Ear Headphone wi...   1399.0     4.1
# 49  Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage...  10999.0     4.1
# 50  boAt Bassheads 900 On Ear Wired Headphones(Car...    649.0     4.2
#
#     No. of Users Rated                                                URL
# 1                    0  https://www.amazon.in/OnePlus-128GB-Storage-Rs...
# 2                    0  https://www.amazon.in/OnePlus-Sierra-Storage-R...
# 3                71842  https://www.amazon.in/Test-Exclusive_2020_1140...
# 4                66529  https://www.amazon.in/Redmi-Carbon-Black-64GB-...
# 5                69234  https://www.amazon.in/Redmi-9A-2GB-32GB-Storag...
# 6                69234  https://www.amazon.in/Redmi-9A-2GB-32GB-Storag...
# 7                69234  https://www.amazon.in/Redmi-9A-Midnight-2GB-32...
# 8                 5413  https://www.amazon.in/Redmi-Note-Deep-Blue-Sto...
# 9                78853  https://www.amazon.in/Samsung-Galaxy-Mirage-12...
# 10               62329  https://www.amazon.in/Black-Wipro-Smart-Color-...
# 11               18227  https://www.amazon.in/OnePlus-Nord-Charcoal-12...
# 12               66529  https://www.amazon.in/Redmi-Sporty-Orange-64GB...
# 13                  19  https://www.amazon.in/boAt-Airdopes-141-Techno...
# 14               71841  https://www.amazon.in/note10/dp/B089MS8NW8?_en...
# 15               78853  https://www.amazon.in/Samsung-Galaxy-Mirage-12...
# 16               66529  https://www.amazon.in/Redmi-Sky-Blue-64GB-Stor...
# 17               71841  https://www.amazon.in/Test-Exclusive_2020_1141...
# 18               71396  https://www.amazon.in/OnePlus-Bullets-Wireless...
# 19                 326  https://www.amazon.in/realme-Storage-Additiona...
# 20                5413  https://www.amazon.in/Redmi-Note-10S/dp/B08LRD...
# 21               78853  https://www.amazon.in/Samsung-Galaxy-Mirage-Bl...
# 22                 326  https://www.amazon.in/realme-Storage-Additiona...
# 23              207396  https://www.amazon.in/boAt-BassHeads-100-Headp...
# 24               57796  https://www.amazon.in/Boat-Bassheads-242-Earph...
# 25               31862  https://www.amazon.in/Airdopes-121v2-Bluetooth...
# 26               14067  https://www.amazon.in/boAt-A325-Tangle-Free-Ch...
# 27               38397  https://www.amazon.in/Rockerz-450-Wireless-Blu...
# 28               51822  https://www.amazon.in/Test-Exclusive_2020_1113...
# 29               12779  https://www.amazon.in/Amazon-FireTV-Stick-4K-A...
# 30               35373  https://www.amazon.in/OnePlus-Buds-Z-White/dp/...
# 31                   0  https://www.amazon.in/OnePlus-256GB-Storage-Rs...
# 32              283906  https://www.amazon.in/boAt-Rockerz-255-Pro-Ear...
# 33               71396  https://www.amazon.in/OnePlus-Bullets-Wireless...
# 34               25239  https://www.amazon.in/boAt-Rockerz-335-Bluetoo...
# 35               59262  https://www.amazon.in/20000mAh-Sandstone-Tripl...
# 36               51822  https://www.amazon.in/Test-Exclusive_2020_1112...
# 37              283906  https://www.amazon.in/255-Bluetooth-Wireless-E...
# 38                7476  https://www.amazon.in/Jabra-Enabled-Wireless-C...
# 39               14695  https://www.amazon.in/Test-Exclusive_2020_1157...
# 40               18227  https://www.amazon.in/OnePlus-Nord-Charcoal-12...
# 41               14695  https://www.amazon.in/Test-Exclusive_2020_1158...
# 42               10325  https://www.amazon.in/Apple-USB-C-Adapter-iPho...
# 43              222161  https://www.amazon.in/Samsung-Galaxy-Ocean-128...
# 44                   0  https://www.amazon.in/OnePlus-Sierra-Storage-R...
# 45               50134  https://www.amazon.in/Rugged-Extra-Tough-Unbre...
# 46               54138  https://www.amazon.in/Redmi-Prime-Storage-Disp...
# 47               34719  https://www.amazon.in/Samsung-Galaxy-M12-Stora...
# 48               38397  https://www.amazon.in/Boat-Rockerz-450-Lightwe...
# 49               34719  https://www.amazon.in/Samsung-Galaxy-M12-Stora...
# 50               47268  https://www.amazon.in/Boat-BassHeads-900-Wired...

# %% [markdown]
# ###### Store Data into a ***.csv*** file

# %%
df.to_csv('Amazon_top50_BestSelling_Electronics_Items.csv')

# %% [markdown]
#  <h3 align= "center"> END </h3>
